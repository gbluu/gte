# %%
import pandas as pd
import os
import glob
import numpy as np

# setting notebook
pd.set_option('display.max_columns', None)

# %%
# my_dir = os.getcwd()
path = r'./data_source/01_bckt_all'

all_files = glob.glob(os.path.join(path , "*.csv"))

# li = []

# # for filename in all_files:
# #     df = pd.read_csv(filename, index_col=None, header=4, dtype=str)
# #     li.append(df)

xuat_cbn = pd.concat((pd.read_csv(f, index_col=None, header=4, dtype=str) for f in all_files), ignore_index=True)

# %%
#Drop null rows
xuat_nonull = xuat_cbn.dropna(subset=['Mã phiếu đề xuất']).reset_index(drop=True)

# %%
# drop unnamed col
xuat_drop_col = xuat_nonull.loc[:, ~xuat_nonull.columns.str.contains('^Unnamed')]

# %%
# filter xuat ban
xuat_ban_only = xuat_drop_col[xuat_drop_col['Loại phiếu'] == 'Xuất bán KH'].reset_index(drop=True)

# %%
# convert number
xuat_cvt_num = xuat_ban_only.copy()
xuat_cvt_num['Số lượng\n(Quantily)'] = xuat_cvt_num['Số lượng\n(Quantily)'].str.strip().str.replace(',','').replace("(", "").replace(")", "").astype(float)
xuat_cvt_num['Tiền hàng\n(Sub Total)'] = xuat_cvt_num['Tiền hàng\n(Sub Total)'].str.strip().str.replace(',','').replace("(", "").replace(")", "").astype(float)

# %%
#convert date
date_cols = ['Ngày phiếu xuất',
              'Ngày hết hạn (Expiry Date)']
xuat_cvt_num[date_cols] = xuat_cvt_num[date_cols].apply(pd.to_datetime, format='%d/%m/%Y')

# %%
xuat_joined = xuat_cvt_num.copy()

# %%
xuat_joined
# Out:
#        Số\nTT   Loại phiếu Ngày phiếu xuất  Mã phiếu xuất Mã phiếu đề xuất  \
# 0           1  Xuất bán KH      2022-01-02  SO-0201220002    SO-0201220001
# 1           2  Xuất bán KH      2022-01-02  SO-0201220002    SO-0201220001
# 2           3  Xuất bán KH      2022-01-02  SO-0201220002    SO-0201220001
# 3           4  Xuất bán KH      2022-01-02  SO-0201220002    SO-0201220001
# 4           5  Xuất bán KH      2022-01-02  SO-0201220004    SO-0201220003
# ...       ...          ...             ...            ...              ...
# 781119  69907  Xuất bán KH      2022-09-20  SO-2009222882    SO-2009222881
# 781120  69908  Xuất bán KH      2022-09-20  SO-2009222884    SO-2009222883
# 781121  69909  Xuất bán KH      2022-09-20  SO-2009222884    SO-2009222883
# 781122  69910  Xuất bán KH      2022-09-20  SO-2009222886    SO-2009222885
# 781123  69912  Xuất bán KH      2022-09-20  SO-2009222888    SO-2009222887
#
#        Ngày hóa đơn    Số hóa đơn Mã KH / NCC\n(Customer Code / Vendor Code)  \
# 0        03/01/2022      00000030                                 COOP0064HP
# 1        03/01/2022      00000030                                 COOP0064HP
# 2        03/01/2022      00000030                                 COOP0064HP
# 3        03/01/2022      00000030                                 COOP0064HP
# 4        03/01/2022      00000031                                 COOP0009HP
# ...             ...           ...                                        ...
# 781119          NaN  Chưa xuất HĐ                                   SHOPEE01
# 781120          NaN  Chưa xuất HĐ                                   SHOPEE01
# 781121          NaN  Chưa xuất HĐ                                   SHOPEE01
# 781122          NaN  Chưa xuất HĐ                                   SHOPEE01
# 781123          NaN  Chưa xuất HĐ                                   SHOPEE01
#
#               Tên KH 2 / NCC  \
# 0       CO.OPMART Phan Thiết
# 3                      Hộp Bánh Qui Nhân Kem Bauducco 1Kg
# 4           Hộp Bánh Qui Bơ Vị Truyền Thống Danesita 454G
# ...                                                   ...
# 781119               Bánh qui bơ hình thú Leibniz Zoo 30g
# 781120                              Kẹo Sữa Galatine 100g
# 781121  Kẹo Sữa Vị Sữa Chua Và Trái Cây Rừng Galatine ...
# 781122  Bánh quế nhân kem ca cao và hạt phỉ Caprice Pa...
# 781123    Kẹo Thổi Bong Bóng Hương Chanh Dây Playmore 40G
#
#                      Tên tiếng Anh\nEnglish Name) Đơn vị\n(Unit)  \
# 0       Danesita Butter Cookies Classy Taste 454G            HỘP
# 1           Danesita Cookies Chocolate Chips 454G            HỘP
# 2                Bahlsen Caroline Collection 322g            HỘP
# 3                     Bauducco Cream Biscuits 1Kg            HỘP
# 4       Danesita Butter Cookies Classy Taste 454G            HỘP
# ...                                           ...            ...
# 781119           Zoo Original butter Biscuits 30g            GÓI
# 781120                 GALATINE PLAIN MILK TABLET            GÓI
# 781121               GALATINE FOREST FRUIT TABLET            GÓI
# 781122                               Caprice 400g            HỘP
# 781123                 Sweet Bubble Passion Fruit            HỘP
#
#         Số lượng\n(Quantily) Giá bán\n(Price)  Tiền hàng\n(Sub Total)  \
# 0                       20.0         103,725                2074500.0
# 1                       10.0         145,350                1453500.0
# 2                       12.0         255,600                3067200.0
# 3                       24.0         207,900                4989600.0
# 4                       20.0         103,725                2074500.0
# ...                      ...              ...                     ...
# 781119                   6.0          13,370                  80222.0
# 781120                   1.0          48,333                  48333.0
# 781121                   1.0          48,333                  48333.0
# 781122                   2.0         111,972                 223944.0
# 781123                   1.0          16,185                  16185.0
#
#        Tiền CK\n(Discount) Tiền thuế\n(VAT) Tồng tiền tt\n(Grand Total)  \
# 0                       0          207,450                   2,281,950
# 1                       0          145,350                   1,598,850
# 2                       0          306,720                   3,373,920
# 3                       0          498,960                   5,488,560
# 4                       0          207,450                   2,281,950
# ...                    ...              ...                         ...
# 781119                  0            6,418                      86,640
# 781120                  0            3,867                      52,200
# 781121                  0            3,867                      52,200
# 781122                  0           17,916                     241,860
# 781123                  0            1,295                      17,480
#
#        Giá vốn\n(Cost Price) Tiền vốn\n(Capital) Mã kho\n(Warehouse Code)  \
# 0                         0                   0                       PVD
# 1                         0                   0                       PVD
# 2                         0                   0                       PVD
# 3                         0                   0                       PVD
# 4                         0                   0                       PVD
# ...                      ...                 ...                      ...
# 781119                    0                   0                  ONLNTL01
# 781120                    0                   0                  ONLNTL01
# 781121                    0                   0                  ONLNTL01
# 781122                    0                   0                  ONLNTL01
# 781123                    0                   0                  ONLNTL01
#
#        Nhóm vật tư chính (Goods KeyGroup)  \
# 0                                DANESITA
# 1                                DANESITA
# 2                                 BAHLSEN
# 3                                BAUDUCCO
# 4                                DANESITA
# ...                                   ...
# 781119                        LEIBNIZ ZOO
# 781120                           GALATINE
# 781121                           GALATINE
# 781122                            CAPRICE
# 781123                           PLAYMORE
#
#        Nhóm vật tư phụ 1 - (Goods SubGroup1)  \
# 0                               Hàng Thời Vụ
# 1                               Hàng Thời Vụ
# 2                                   Bánh Kẹo
# 3                               Hàng Thời Vụ
# 4                               Hàng Thời Vụ
# ...                                      ...
# 781119                              Bánh Kẹo
# 781120                              Bánh Kẹo
# 781121                              Bánh Kẹo
# 781122                              Bánh Kẹo
# 781123                              Bánh Kẹo
#
#        Nhóm vật tư phụ 2 - (Goods SubGroup2)  \
# 0                                Bánh qui bơ
# 1                                Bánh qui bơ
# 2                                Bánh Pastry
# 3                                   Bánh Qui
# 4                                Bánh qui bơ
# ...                                      ...
# 781119                              Bánh Qui
# 781120                                   Kẹo
# 781121                                   Kẹo
# 781122                              Bánh xốp
# 781123                           Kẹo đồ chơi
#
#        Nhóm vật tư phụ 3 - (Goods SubGroup3)               LOT  \
# 0                      Bánh Qui Bơ Hộp Thiếc   25/11/2021-0380
# 1                Bánh Qui Sô Cô La Hộp Thiếc   25/11/2021-8727
# 2                                  Hộp Thiếc   08/11/2021-0132
# 3                Bánh qui nhân kem hộp thiếc  17/11/2021-1386R
# 4                      Bánh Qui Bơ Hộp Thiếc   25/11/2021-0380
# ...                                      ...               ...
# 781119                       Bánh Qui Trẻ Em              0101
# 781120                               Kẹo Sữa              0101
# 781121                               Kẹo Sữa              0101
# 781122                          Bánh Ống Quế              0101
# 781123                           Kẹo đồ chơi              0101
#
#                                 HSD Ngày SX (Manufactur Date)  \
# 0       Lô hàng HSD ngày 30/03/2023                       NaN
# 1       Lô hàng HSD ngày 05/03/2023                       NaN
# 2       Lô hàng HSD ngày 25/08/2022                       NaN
# 3       Lô hàng HSD ngày 01/09/2022                       NaN
# 4       Lô hàng HSD ngày 30/03/2023                       NaN
# ...                             ...                       ...
# 781119  Lô hàng HSD ngày 06/03/2023                       NaN
# 781120  Lô hàng HSD ngày 09/12/2022                       NaN
# 781121  Lô hàng HSD ngày 23/08/2023                       NaN
# 781122  Lô hàng HSD ngày 05/05/2023                       NaN
# 781123  Lô hàng HSD ngày 04/02/2024                       NaN
#
#        Ngày hết hạn (Expiry Date) Số đơn đặt hàng Ngày đặt hàng  \
# 0                      2023-03-30     71442224-00    29/12/2021
# 1                      2023-03-05     71442224-00    29/12/2021
# 2                      2022-08-25     71442224-00    29/12/2021
# 3                      2022-09-01     71442224-00    29/12/2021
# 4                      2023-03-30     71442233-00    29/12/2021
# ...                           ...             ...           ...
# 781119                 2023-03-06  2209185K9V39R4    18/09/2022
# 781120                 2022-12-09  2209185VBD16HJ    18/09/2022
# 781121                 2023-08-23  2209185VBD16HJ    18/09/2022
# 781122                 2023-05-05  22091861QV04AP    18/09/2022
# 781123                 2024-02-04  2209196D0325JT    19/09/2022
#
#                             Diễn giải Mã Phiếu đề xuất của HP/ RW
# 0                                 NaN                 71442224-00
# 1                                 NaN                 71442224-00
# 2                                 NaN                 71442224-00
# 3                                 NaN                 71442224-00
# 4                                 NaN                 71442233-00
# ...                               ...                         ...
# 781119  18 ĐƠN SHOPEE NGÀY 19.09.2022            SP2209185K9V39R4
# 781120  18 ĐƠN SHOPEE NGÀY 19.09.2022            SP2209185VBD16HJ
# 781121  18 ĐƠN SHOPEE NGÀY 19.09.2022            SP2209185VBD16HJ
# 781122  18 ĐƠN SHOPEE NGÀY 19.09.2022            SP22091861QV04AP
# 781123  18 ĐƠN SHOPEE NGÀY 19.09.2022            SP2209196D0325JT
#
# [781124 rows x 40 columns]
